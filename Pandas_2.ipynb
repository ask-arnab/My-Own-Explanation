# %%
pwd
# Out:
# 'C:\\Users\\arnab\\Documents\\Python Programming\\ML'

# %%
import pandas as pd
import numpy as np

# %%
dict = {
    "Name" : ["X","Y","Z"],
    "Age" : [15,18,21]
}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age'])

# %%
dict.values()
# Out:
# dict_values([['X', 'Y', 'Z'], [15, 18, 21]])

# %%
df = pd.DataFrame(dict)
df.head()
# Out:
#   Name  Age
# 0    X   15
# 1    Y   18
# 2    Z   21

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
#df.drop -> drop any columns or rows

# %%
#df.drop(0) #drop rows
df.drop("cgpa",axis=1,inplace=True) #Drop columns

# %%
#Inplace -> Change in existing dataframe

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.rename(columns = {'cgpa' : 'Marks Obtained'},inplace=True)

# %%
df.head()
# Out:
#    Marks Obtained  package
# 0            6.89     3.26
# 1            5.12     1.98
# 2            7.82     3.25
# 3            7.42     3.67
# 4            6.94     3.57

# %%
#loc and iloc

# %%
df.loc[0,"Marks Obtained"]
# Out:
# 6.89

# %%
df.loc[0,"package"]
# Out:
# 3.26

# %%
df.iloc[0,1]
# Out:
# 3.26

# %%
df.nunique()
# Out:
# Marks Obtained    163
# package           138
# dtype: int64

# %%
#df.info(), df.describe()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Marks Obtained  200 non-null    float64
#  1   package         200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df['Marks Obtained'].duplicated().sum()
# Out:
# 37

# %%
df.describe()
# Out:
#        Marks Obtained     package
# count      200.000000  200.000000
# mean         6.990500    2.996050
# std          1.069409    0.691644
# min          4.260000    1.370000
# 25%          6.190000    2.487500
# 50%          6.965000    2.995000
# 75%          7.737500    3.492500
# max          9.580000    4.620000

# %%
#df.mean(), df.median(), df.sum(), df.min(), df.std(), df.max(), df.value_counts(), df.quantile()

# %%
df.mean() #-> mean value
#df['package'].mean()
# Out:
# Marks Obtained    6.99050
# package           2.99605
# dtype: float64

# %%
df.median() #Meadian value
# Out:
# Marks Obtained    6.965
# package           2.995
# dtype: float64

# %%
df['package'].value_counts() #Catagorical Data
# Out:
# package
# 3.08    4
# 2.99    4
# 2.60    4
# 2.72    3
# 3.33    3
#        ..
# 4.03    1
# 3.62    1
# 2.94    1
# 1.63    1
# 2.33    1
# Name: count, Length: 138, dtype: int64

# %%
df.quantile() #percentile
# Out:
# Marks Obtained    6.965
# package           2.995
# Name: 0.5, dtype: float64

# %%
Q1 = df['Marks Obtained'].quantile(0.25) #percentile

# %%
Q3 = df['Marks Obtained'].quantile(0.75) #percentile

# %%
IQR = Q3-Q1 # Inter Quartile Region -> Outlier detection
print(IQR)
# Out:
# 1.5475000000000003

# %%
#Sort values

# %%
df.sort_values(by='Marks Obtained',ascending=False,inplace=False,ignore_index=False)
# Out:
#      Marks Obtained  package
# 50             9.58     4.43
# 40             9.38     4.02
# 169            9.31     4.37
# 51             9.26     3.79
# 63             9.16     4.25
# ..              ...      ...
# 143            4.85     1.54
# 85             4.79     1.48
# 88             4.73     1.48
# 193            4.57     1.94
# 84             4.26     1.53
#
# [200 rows x 2 columns]

# %%
#String Methods
dict = {
    "Name" : ["Ram" , "Shyam", "Arjun", "Karna"],
    "Age" : [21,26,35,28]
}

# %%
df_str = pd.DataFrame(dict)

# %%
df_str.head()
# Out:
#     Name  Age
# 0    Ram   21
# 1  Shyam   26
# 2  Arjun   35
# 3  Karna   28

# %%
#df_str['Name'].str.lower()
df_str['Name'].str.upper()
#In NLP domain it is used.
# Out:
# 0      RAM
# 1    SHYAM
# 2    ARJUN
# 3    KARNA
# Name: Name, dtype: object

# %%
df_str = pd.DataFrame({'Name' : ['maximum', 'Maxxy', 'Mini', 'MaX']})

# %%
df_str[df_str['Name'].str.contains('Max')] #Case Sensative
# Out:
#     Name
# 1  Maxxy

# %%
df_str[df_str['Name'].str.contains('Max',case=False)] #Case insensative
# Out:
#       Name
# 0  maximum
# 1    Maxxy
# 3      MaX

# %%
#Tokenization

# %%
data = {
    "Text" : ["Einstein was a good scientist", "Virat Kohli is a good cricketer", "Messi is bad at cricket"]
}
df_str = pd.DataFrame(data)
df_str.head()
# Out:
#                               Text
# 0    Einstein was a good scientist
# 1  Virat Kohli is a good cricketer
# 2          Messi is bad at cricket

# %%
df_str['Split_Text'] = df_str['Text'].str.split()

# %%
df_str
# Out:
#                               Text                              Split_Text
# 0    Einstein was a good scientist     [Einstein, was, a, good, scientist]
# 1  Virat Kohli is a good cricketer  [Virat, Kohli, is, a, good, cricketer]
# 2          Messi is bad at cricket           [Messi, is, bad, at, cricket]

# %%
#Why this is imp?
#Any continious signal can be converted into a series of sine or cosine waves -> Fourier Analysis

# %%
df.drop("Split_Text", axis =1 ,inplace=True)

# %%
df.head()
# Out:
#    Marks Obtained  package
# 0            6.89     3.26
# 1            5.12     1.98
# 2            7.82     3.25
# 3            7.42     3.67
# 4            6.94     3.57

# %%
len(df)
# Out:
# 200

# %%
for i in range(len(df)):
    if (df.iloc[i,0] < 6):
        df.iloc[i,0] = 0
    else:
        pass

# %%
df.head(3)
#Complexity -> del(t) * n(no. of rows)
# Out:
#    Marks Obtained  package
# 0            6.89     3.26
# 1            0.00     1.98
# 2            7.82     3.25

# %%
df['package'] = np.where(df['package']<3,0,df['package'])
#Complexity = cons.

# %%
df.head()
# Out:
#    Marks Obtained  package
# 0            6.89     3.26
# 1            0.00     0.00
# 2            7.82     3.25
# 3            7.42     3.67
# 4            6.94     3.57

# %%
import seaborn as sns

# %%
sns.distplot(df.iloc[:,0])
sns.distplot(df.iloc[:,1])
# Out:
# C:\Users\arnab\AppData\Local\Temp\ipykernel_12440\3807622871.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.iloc[:,0])
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\arnab\AppData\Local\Temp\ipykernel_12440\3807622871.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
sns.boxplot(df.iloc[:,0])
# Out:
# <Axes: >

# %%
df_loan = pd.read_csv("loan_data.csv")

# %%
df_loan.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
#Checking Null values

# %%
df_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
df_loan.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
sns.distplot(df_loan.iloc[:,0])
# Out:
# C:\Users\arnab\AppData\Local\Temp\ipykernel_12440\2001552248.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_loan.iloc[:,0])
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='person_age', ylabel='Density'>

# %%
sns.boxplot(df_loan.iloc[:,0])
# Out:
# <Axes: >

# %%
Q1 = df_loan['person_age'].quantile(0.25)

# %%
Q3 = df_loan['person_age'].quantile(0.75)

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 6.0

# %%
Q1-1.5*IQR
# Out:
# 15.0

# %%
Q3+1.5*IQR
# Out:
# 39.0

# %%
df_loan = df_loan[df_loan['person_age']<=39]
#df_loan_outlier_removed = df_loan[df_loan['person_age']<=39]

# %%
df_loan
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
sns.boxplot(df_loan.iloc[:,0])
# Out:
# <Axes: >

# %%
sns.distplot(df_loan.iloc[:,0])
# Out:
# C:\Users\arnab\AppData\Local\Temp\ipykernel_12440\2001552248.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_loan.iloc[:,0])
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='person_age', ylabel='Density'>

# %%
#Standarization
#x_var = x-mean/sigma

# %%
df_loan['person_gender'].value_counts().values
# Out:
# array([23522, 19290], dtype=int64)

# %%
sns.barplot(x=df_loan['person_gender'].value_counts().keys(),y=df_loan['person_gender'].value_counts().values)
# Out:
# <Axes: xlabel='person_gender'>

# %%
sns.barplot(x=df_loan['person_education'].value_counts().keys(),y=df_loan['person_education'].value_counts().values)
# Out:
# <Axes: xlabel='person_education'>

# %%
sns.distplot(df_loan.iloc[:,4])
# Out:
# C:\Users\arnab\AppData\Local\Temp\ipykernel_12440\3592065163.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_loan.iloc[:,4])
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='person_emp_exp', ylabel='Density'>

# %%
df_loan['loan_status'].value_counts()
#Imbalance Dataset
# Out:
# loan_status
# 0    33279
# 1     9533
# Name: count, dtype: int64
