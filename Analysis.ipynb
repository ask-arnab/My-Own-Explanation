# %%
# EDA : Exoplarory Data Analysis

# %%
# Univariate and Bi-variate Analyis

# %%
# Univarite Analysis : When an analysis is done on a single column
# Bi-varite/Multivariate Analysis : When an analysis is done on more than one column

# %%
# Titanic Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df.drop(["PassengerId","Name","Ticket"],axis=1,inplace=True)

# %%
# Univarite Analysis

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.barplot(x=df["Pclass"].value_counts().keys(),y=df["Pclass"].value_counts().values)
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.barplot(x=df["Survived"].value_counts().keys(),y=df["Survived"].value_counts().values)
# Out:
# <Axes: xlabel='Survived'>

# %%
df["Pclass"].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
#Pi - chart

# %%
df["Pclass"].value_counts().plot(kind = 'pie',autopct="%0.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["Sex"].value_counts().plot(kind = 'pie',autopct="%0.2f")
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["Age"],bins=8)
# Out:
# (array([ 64., 115., 230., 155.,  86.,  42.,  17.,   5.]),
#  array([ 0.42  , 10.3675, 20.315 , 30.2625, 40.21  , 50.1575, 60.105 ,
#         70.0525, 80.    ]),
#  <BarContainer object of 8 artists>)

# %%
sns.distplot(df["Age"],hist=False)
# Out:
# C:\Users\arnab\AppData\Local\Temp\ipykernel_23844\321006256.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],hist=False)
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#Boxplot -> To search outliers

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: >

# %%
tips = pd.read_csv("tip.csv")

# %%
titanic = pd.read_csv("Titanic-Dataset.csv")

# %%
flights = pd.read_csv("flights.csv")

# %%
from sklearn.datasets import load_iris
IRIS = load_iris()
iris = pd.DataFrame(data = IRIS.data,columns=IRIS.feature_names)

# %%
iris['target'] = IRIS.target

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Numerical - Numerical
# catagorical - Catagorical
# Cat- numerical

# %%
# Numwrical-Numerical

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=tips["total_bill"],y=tips["tip"],hue=tips["sex"],style=tips["time"],size=tips["size"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#Numerical-Catagorical

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x=titanic["Pclass"],y=titanic["Fare"],hue=titanic["Sex"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x=tips["size"],y=tips["tip"])
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.barplot(x=tips["sex"],y=tips["tip"])
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
#KDE

# %%
sns.distplot(titanic[titanic["Survived"]==0]["Age"],hist=False)
sns.distplot(titanic[titanic["Survived"]==1]["Age"],hist=False)
# Out:
# C:\Users\arnab\AppData\Local\Temp\ipykernel_23844\3683906070.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic["Survived"]==0]["Age"],hist=False)
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\arnab\AppData\Local\Temp\ipykernel_23844\3683906070.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
# Cat- Cat

# %%
sns.heatmap(pd.crosstab(titanic["Pclass"],titanic["Survived"]),cmap='crest')
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
#pairplot

# %%
iris['species'] = iris['target'].map({
    0 : 'setosa',
    1: 'versicolor',
    2 : 'virginica'
})

# %%
iris.drop("target",axis=1,inplace=True)

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
sns.pairplot(iris,hue='species')
# Out:
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
new = flights.groupby('year').sum().reset_index()

# %%
sns.lineplot(x=new["year"],y=new["passengers"])
# Out:
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\arnab\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.heatmap(pd.pivot_table(flights,values="passengers",index="month",columns="year"),linewidth=2)
# Out:
# <Axes: xlabel='year', ylabel='month'>
