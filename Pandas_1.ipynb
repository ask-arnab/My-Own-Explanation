# %%
import pandas as pd

# %%
import numpy as np

# %%
#Dictonary
dict = {
    "Name" : ["Ram", "Shyam" ,"Laxman", "Arjun"],
    "Age" : [20,25,24,27]
}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age'])

# %%
dict.values()
# Out:
# dict_values([['Ram', 'Shyam', 'Laxman', 'Arjun'], [20, 25, 24, 27]])

# %%
#In Dict. the combination is always key+value pair

# %%
df = pd.DataFrame(dict) # Dict -> DataFrame

# %%
df.head(2) # df.head(n) n-> no. of rows showing
# Out:
#     Name  Age
# 0    Ram   20
# 1  Shyam   25

# %%
df.tail(2)
# Out:
#      Name  Age
# 2  Laxman   24
# 3   Arjun   27

# %%
np.random.random((5,2)) #Returns a 2D numpy-array
# Out:
# array([[0.52418543, 0.25175363],
#        [0.96147371, 0.14811858],
#        [0.73102571, 0.39238513],
#        [0.81012756, 0.5004988 ],
#        [0.19645498, 0.51378588]])

# %%
list('ABCD')
# Out:
# ['A', 'B', 'C', 'D']

# %%
DF = pd.DataFrame(np.random.random((100,4)),columns=list('ABCD'))

# %%
DF.tail(8)
# Out:
#            A         B         C         D
# 92  0.811867  0.346262  0.292061  0.771622
# 93  0.334388  0.328841  0.902469  0.787380
# 94  0.327016  0.513149  0.914596  0.509046
# 95  0.487651  0.213745  0.689277  0.919971
# 96  0.357881  0.991126  0.444791  0.792485
# 97  0.914601  0.402955  0.413536  0.805392
# 98  0.292912  0.545562  0.245429  0.323028
# 99  0.805233  0.793345  0.664585  0.942082

# %%
pwd
# Out:
# 'C:\\Users\\arnab\\Documents\\Python Programming'

# %%
cd ML/
# Out:
# C:\Users\arnab\Documents\Python Programming\ML

# %%
df = pd.read_csv("placement.csv") #csv -> Pandas Dataframe

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df[df["cgpa"]>6.0]
#df[df["package"]]>4.0
# Out:
#      cgpa  package
# 0    6.89     3.26
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# 5    7.89     2.99
# ..    ...      ...
# 194  7.89     3.67
# 195  6.93     2.46
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [162 rows x 2 columns]

# %%
#df.info() df.describe()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.describe() #-> Statistical Counts
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
#loc and iloc

# %%
#A DataFrame -> A Matrix with n rows and m columns

# %%
#loc
#df.loc[a1,a2] -> a1 = row no, a2 = columns name

# %%
df.loc[0,'cgpa']
# Out:
# 6.89

# %%
#iloc
##df.iloc[a1,a2] -> a1 = row no, a2 = columns number

# %%
df.iloc[0,0]
# Out:
# 6.89

# %%
#df.drop,df.dropna,df.rename,df.duplicated,df.drop_duplicate

# %%
new_df = df.drop(0,inplace=False)

# %%
df.drop(['cgpa'],axis=1,inplace= False)
# Out:
#      package
# 0       3.26
# 1       1.98
# 2       3.25
# 3       3.67
# 4       3.57
# ..       ...
# 195     2.46
# 196     2.57
# 197     3.24
# 198     3.96
# 199     2.33
#
# [200 rows x 1 columns]

# %%
#df.dropna -> Remove Missing value

# %%
df.iloc[14,0] = np.NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     199 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [199 rows x 2 columns]

# %%
df.iloc[2,0] = np.NaN

# %%
#Replace NaN value by mean,meadian,1 ,2 any value
df.fillna(value=df['cgpa'].mean())
# Out:
#          cgpa  package
# 0    6.890000     3.26
# 1    5.120000     1.98
# 2    6.982576     3.25
# 3    7.420000     3.67
# 4    6.940000     3.57
# ..        ...      ...
# 195  6.930000     2.46
# 196  5.890000     2.57
# 197  7.210000     3.24
# 198  7.630000     3.96
# 199  6.220000     2.33
#
# [199 rows x 2 columns]

# %%
#rename

# %%
df.rename(columns = {'cgpa' : 'Marks Obtain'},inplace= False)
# Out:
#      Marks Obtain  package
# 0            6.89     3.26
# 1            5.12     1.98
# 2             NaN     3.25
# 3            7.42     3.67
# 4            6.94     3.57
# ..            ...      ...
# 195          6.93     2.46
# 196          5.89     2.57
# 197          7.21     3.24
# 198          7.63     3.96
# 199          6.22     2.33
#
# [199 rows x 2 columns]

# %%
df.dropna(inplace=True)

# %%
#Finding Duplicate values

# %%
df['cgpa'].duplicated().sum()
# Out:
# 37

# %%
df[df['cgpa'].duplicated()]
# Out:
#      cgpa  package
# 18   6.94     2.98
# 25   7.28     3.65
# 26   8.31     3.42
# 41   6.89     2.70
# 56   5.84     2.74
# 64   7.36     2.92
# 68   7.56     2.99
# 74   6.85     3.44
# 76   6.94     3.15
# 83   8.44     3.49
# 96   7.11     2.61
# 99   6.61     3.24
# 111  5.42     2.25
# 113  6.94     2.37
# 114  5.84     1.87
# 122  5.12     2.01
# 132  5.84     2.48
# 135  6.10     2.60
# 140  7.91     3.15
# 142  6.93     3.04
# 145  5.84     2.18
# 146  6.07     2.46
# 157  6.47     2.70
# 158  5.95     3.04
# 161  7.30     3.33
# 170  6.22     2.87
# 172  6.93     2.51
# 173  6.75     2.56
# 179  7.14     3.03
# 180  6.19     2.72
# 183  7.28     2.72
# 190  6.19     2.69
# 191  7.28     3.48
# 194  7.89     3.67
# 195  6.93     2.46
# 198  7.63     3.96
# 199  6.22     2.33

# %%
df.drop_duplicates(subset=['cgpa'],inplace=False)
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 3    7.42     3.67
# 4    6.94     3.57
# 5    7.89     2.99
# ..    ...      ...
# 189  8.11     4.06
# 192  8.25     3.75
# 193  4.57     1.94
# 196  5.89     2.57
# 197  7.21     3.24
#
# [161 rows x 2 columns]

# %%
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 3    7.42     3.67
# 4    6.94     3.57
# 5    7.89     2.99
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [198 rows x 2 columns]

# %%
df.nunique().values
# Out:
# array([161, 137], dtype=int64)

# %%
import seaborn as sns

# %%
sns.barplot(x=df.nunique().keys(),y=df.nunique().values)
# Out:
# <Axes: >
